# %% [markdown]
# ### My analytics shows:
# ## The mean of each column where ivt ==0 or the mean of each column where ivt is not equal to zero (THE RESULT I GET IS AMAZING MEAN OF EACH COLUMNS WHERE IVT > 0 IS SLIGHTLY HIGHER THAN WHERE IVT==0 )

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data.csv', header=[1])

# %%
data['Date']=pd.to_datetime(data['Date'] )

# %%
data=data.drop('1' , axis=1)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(data)
# Out:
#                   Date  unique_idfas  unique_ips  unique_uas  total_requests  \
# 0  2025-09-11 14:00:00          3535        3535          17            3577
# 1  2025-09-11 15:00:00          7254        7254          17            7361
# 2  2025-09-11 16:00:00         13737       13737          17           14073
# 3  2025-09-11 17:00:00         13800       13800          18           14074
# 4  2025-09-11 18:00:00          8696        8696          19            8796
# 5  2025-09-11 19:00:00          8182        8182          20            8273
# 6  2025-09-11 20:00:00         10707       10707          17           10860
# 7  2025-09-11 21:00:00          9634        9634          17            9752
# 8  2025-09-11 22:00:00         12420       12420          19           12576
# 9  2025-09-11 23:00:00          9843        9843          20            9938
# 10 2025-09-12 00:00:00         11655       11655          21           11806
# ...

# %%
data = data.set_index('Date')

# %%
data
# Out:
#                      unique_idfas  unique_ips  unique_uas  total_requests  \
# Date
# 2025-09-11 14:00:00          3535        3535          17            3577
# 2025-09-11 15:00:00          7254        7254          17            7361
# 2025-09-11 16:00:00         13737       13737          17           14073
# 2025-09-11 17:00:00         13800       13800          18           14074
# 2025-09-11 18:00:00          8696        8696          19            8796
# 2025-09-11 19:00:00          8182        8182          20            8273
# 2025-09-11 20:00:00         10707       10707          17           10860
# 2025-09-11 21:00:00          9634        9634          17            9752
# 2025-09-11 22:00:00         12420       12420          19           12576
# 2025-09-11 23:00:00          9843        9843          20            9938
# 2025-09-12 00:00:00         11655       11655          21           11806
# 2025-09-12 01:00:00          9083        9083          20            9124
# ...

# %% [markdown]
# Here i will explain my analytics for the day 2025-09-11 for different hour

# %%
data__date_11=data['2025-09-11 14:00:00' : '2025-09-11 23:00:00']
data__date_11
# Out:
#                      unique_idfas  unique_ips  unique_uas  total_requests  \
# Date
# 2025-09-11 14:00:00          3535        3535          17            3577
# 2025-09-11 15:00:00          7254        7254          17            7361
# 2025-09-11 16:00:00         13737       13737          17           14073
# 2025-09-11 17:00:00         13800       13800          18           14074
# 2025-09-11 18:00:00          8696        8696          19            8796
# 2025-09-11 19:00:00          8182        8182          20            8273
# 2025-09-11 20:00:00         10707       10707          17           10860
# 2025-09-11 21:00:00          9634        9634          17            9752
# 2025-09-11 22:00:00         12420       12420          19           12576
# 2025-09-11 23:00:00          9843        9843          20            9938
#
#                      requests_per_idfa  impressions  impressions_per_idfa  \
# Date
# ...

# %% [markdown]
# extract the data from data_date_11 where ivt >0 and ivt ==0

# %%
data_data_11_above_zero=data__date_11[data__date_11['IVT'] > 0]

# %%
data_data_11_equal_zero=data__date_11[data__date_11['IVT'] == 0]

# %% [markdown]
# Get the mean of each columns from the both data frame

# %%
#Value of ivt > 0 
data_data_11_above_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         8998.800000
# unique_ips           8998.800000
# unique_uas             18.400000
# requests_per_idfa       1.012952
# idfa_ua_ratio         488.512745
# dtype: float64

# %%
data_data_11_equal_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         10562.800000
# unique_ips           10562.800000
# unique_uas              17.800000
# requests_per_idfa        1.015512
# idfa_ua_ratio          595.191331
# dtype: float64

# %%
data__date_12=data['2025-09-12 14:00:00' : '2025-09-12 23:00:00']

# %%
data__date_12
# Out:
#                      unique_idfas  unique_ips  unique_uas  total_requests  \
# Date
# 2025-09-12 14:00:00         20486       20483          20           21779
# 2025-09-12 15:00:00         12651       12651          19           13017
# 2025-09-12 16:00:00         12936       12936          19           13263
# 2025-09-12 17:00:00         13394       13394          19           13708
# 2025-09-12 18:00:00         55797       55795          21           60342
# 2025-09-12 19:00:00         66294       66292          19           72581
# 2025-09-12 20:00:00         78823       78822          21           85521
# 2025-09-12 21:00:00         44541       44540          22           46588
# 2025-09-12 22:00:00         49957       49953          22           52110
# 2025-09-12 23:00:00         50434       50430          21           52672
#
#                      requests_per_idfa  impressions  impressions_per_idfa  \
# Date
# ...

# %%
data__date_12_above_zero=data__date_12[data__date_12['IVT'] > 0]
data__date_12_equal_zero=data__date_12[data__date_12['IVT'] == 0]

# %%
data__date_12_above_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         42778.500000
# unique_ips           42776.875000
# unique_uas              20.375000
# requests_per_idfa        1.057770
# idfa_ua_ratio         2075.635899
# dtype: float64

# %%
data__date_12_equal_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         31542.500000
# unique_ips           31540.500000
# unique_uas              20.000000
# requests_per_idfa        1.036653
# idfa_ua_ratio         1533.730577
# dtype: float64

# %%
data__date_13=data['2025-09-13 00:00:00' : '2025-09-13 23:00:00']

# %%
data__date_13
# Out:
#                      unique_idfas  unique_ips  unique_uas  total_requests  \
# Date
# 2025-09-13 00:00:00         32161       32157          19           33306
# 2025-09-13 01:00:00         16401       16400          18           16668
# 2025-09-13 02:00:00         18171       18171          18           18438
# 2025-09-13 03:00:00         12518       12518          19           12631
# 2025-09-13 04:00:00         37790       37788          22           38887
# 2025-09-13 05:00:00         15328       15328          18           15608
# 2025-09-13 06:00:00         23243       23240          21           23899
# 2025-09-13 07:00:00          7427        7427          19            7541
# 2025-09-13 08:00:00          8687        8685          19            8957
# 2025-09-13 09:00:00          8527        8527          18            8818
# 2025-09-13 10:00:00          9002        9002          18            9380
# 2025-09-13 11:00:00          8816        8816          20            9182
# ...

# %%
data__date_13_above_zero=data__date_13[data__date_13['IVT'] > 0]
data__date_13_equal_zero=data__date_13[data__date_13['IVT']==0]

# %%
data__date_13_above_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         23627.733333
# unique_ips           23626.266667
# unique_uas              19.400000
# requests_per_idfa        1.031458
# idfa_ua_ratio         1150.785221
# dtype: float64

# %%
data__date_13_equal_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         11244.777778
# unique_ips           11244.444444
# unique_uas              18.111111
# requests_per_idfa        1.019674
# idfa_ua_ratio          622.815560
# dtype: float64

# %%
data__date_14=data['2025-09-14 00:00:00	' : '2025-09-14 23:00:00']

# %%
data__date_14_above_zero=data__date_14[data__date_14['IVT'] > 0]
data__date_14_equal_zero=data__date_14[data__date_14['IVT'] == 0]

# %%
data__date_14_above_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         19591.600000
# unique_ips           19590.466667
# unique_uas              18.733333
# requests_per_idfa        1.025262
# idfa_ua_ratio         1011.735477
# dtype: float64

# %%
data__date_14_equal_zero[['unique_idfas' , 'unique_ips' ,'unique_uas' ,'requests_per_idfa' ,'idfa_ua_ratio']].mean()
# Out:
# unique_idfas         17241.555556
# unique_ips           17240.444444
# unique_uas              19.777778
# requests_per_idfa        1.033392
# idfa_ua_ratio          869.918509
# dtype: float64

# %%
data__date_15=data['2025-09-15 00:00:00	' : '2025-09-15 23:00:00']

# %%
data__date_15
# Out:
#                      unique_idfas  unique_ips  unique_uas  total_requests  \
# Date
# 2025-09-15 00:00:00         40618       40616          20           42359
# 2025-09-15 01:00:00         37731       37728          19           39050
#
#                      requests_per_idfa  impressions  impressions_per_idfa  \
# Date
# 2025-09-15 00:00:00           1.042863            0                     0
# 2025-09-15 01:00:00           1.034958            0                     0
#
#                      idfa_ip_ratio  idfa_ua_ratio       IVT
# Date
# 2025-09-15 00:00:00       1.000049    2030.900000  0.005935
# 2025-09-15 01:00:00       1.000080    1985.842105  0.000000

# %%
# In the above case u can see each columns avg is larger than the avg where ivt=0

# %%
# lets make a graph of mean values 
graph={
    'Date':['2025-09-11' , '2025-09-12','2025-09-13','2025-09-14','2025-09-15'],
    'Unique_idfas_mean' :['8998.800000' ,'42778.500000','23627.733333','19591.600000','40618'],
    'unique_ips' :['8998.800000' , '42776.875000' ,'23626.266667' ,'19590.466667' ,'40616'],
    'unique_uas' : ['18.400000' , '20.375000', ' 19.400000','18.733333','20'],
    'requests_per_idfa':['1.012952' ,'1.057770' ,'1.031458' ,'1.025262' ,'1.042863'],
    'idfa_ua_ratio' : ['488.512745' ,'2075.635899' ,'1150.785221' ,'1011.735477' ,'2030.900000']
}
df_1=pd.DataFrame(graph)

# %%
df_1
# Out:
#          Date Unique_idfas_mean    unique_ips  unique_uas requests_per_idfa  \
# 0  2025-09-11       8998.800000   8998.800000   18.400000          1.012952
# 1  2025-09-12      42778.500000  42776.875000   20.375000          1.057770
# 2  2025-09-13      23627.733333  23626.266667   19.400000          1.031458
# 3  2025-09-14      19591.600000  19590.466667   18.733333          1.025262
# 4  2025-09-15             40618         40616          20          1.042863
#
#   idfa_ua_ratio
# 0    488.512745
# 1   2075.635899
# 2   1150.785221
# 3   1011.735477
# 4   2030.900000

# %%
df_1.set_index('Date' , inplace=True)

# %%
df_1
# Out:
#            Unique_idfas_mean    unique_ips  unique_uas requests_per_idfa  \
# Date
# 2025-09-11       8998.800000   8998.800000   18.400000          1.012952
# 2025-09-12      42778.500000  42776.875000   20.375000          1.057770
# 2025-09-13      23627.733333  23626.266667   19.400000          1.031458
# 2025-09-14      19591.600000  19590.466667   18.733333          1.025262
# 2025-09-15             40618         40616          20          1.042863
#
#            idfa_ua_ratio
# Date
# 2025-09-11    488.512745
# 2025-09-12   2075.635899
# 2025-09-13   1150.785221
# 2025-09-14   1011.735477
# 2025-09-15   2030.900000

# %%
df_1 = df_1.apply(pd.to_numeric, errors='coerce')  # Converts all columns

# %%
df_1.plot(y='Unique_idfas_mean'  , figsize=(30 , 15))
plt.show()

# %%
graph_1={
    'Date':['2025-09-11' , '2025-09-12','2025-09-13','2025-09-14','2025-09-15'],
    'Unique_idfas_mean' :['10562.800000' ,'31542.500000','11244.777778','17241.555556','37731'],
    'unique_ips' :['10562.800000' , '31540.500000' ,'11244.444444' ,'17240.444444' ,'37728'],
    'unique_uas' : ['17.800000' , '20.000000', '18.111111','19.777778','19	'],
    'requests_per_idfa':['1.015512' ,'1.036653' ,'1.019674' ,' 1.033392' ,'1.034958	'],
    'idfa_ua_ratio' : ['595.191331' ,'1533.730577' ,'622.815560' ,'869.918509' ,'1985.842105']
}
df_2=pd.DataFrame(graph_1 )

# %%
df_2
# Out:
#          Date Unique_idfas_mean    unique_ips unique_uas requests_per_idfa  \
# 0  2025-09-11      10562.800000  10562.800000  17.800000          1.015512
# 1  2025-09-12      31542.500000  31540.500000  20.000000          1.036653
# 2  2025-09-13      11244.777778  11244.444444  18.111111          1.019674
# 3  2025-09-14      17241.555556  17240.444444  19.777778          1.033392
# 4  2025-09-15             37731         37728       19\t        1.034958\t
#
#   idfa_ua_ratio
# 0    595.191331
# 1   1533.730577
# 2    622.815560
# 3    869.918509
# 4   1985.842105

# %%
df_2.set_index('Date' , inplace=True)

# %%
df_2
# Out:
#            Unique_idfas_mean    unique_ips unique_uas requests_per_idfa  \
# Date
# 2025-09-11      10562.800000  10562.800000  17.800000          1.015512
# 2025-09-12      31542.500000  31540.500000  20.000000          1.036653
# 2025-09-13      11244.777778  11244.444444  18.111111          1.019674
# 2025-09-14      17241.555556  17240.444444  19.777778          1.033392
# 2025-09-15             37731         37728       19\t        1.034958\t
#
#            idfa_ua_ratio
# Date
# 2025-09-11    595.191331
# 2025-09-12   1533.730577
# 2025-09-13    622.815560
# 2025-09-14    869.918509
# 2025-09-15   1985.842105

# %%
df_2 = df_2.apply(pd.to_numeric, errors='coerce')  # Converts all columns

# %%
df_2
# Out:
#             Unique_idfas_mean    unique_ips  unique_uas  requests_per_idfa  \
# Date
# 2025-09-11       10562.800000  10562.800000   17.800000           1.015512
# 2025-09-12       31542.500000  31540.500000   20.000000           1.036653
# 2025-09-13       11244.777778  11244.444444   18.111111           1.019674
# 2025-09-14       17241.555556  17240.444444   19.777778           1.033392
# 2025-09-15       37731.000000  37728.000000   19.000000           1.034958
#
#             idfa_ua_ratio
# Date
# 2025-09-11     595.191331
# 2025-09-12    1533.730577
# 2025-09-13     622.815560
# 2025-09-14     869.918509
# 2025-09-15    1985.842105

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_1.index, df_1['Unique_idfas_mean'], label='Value from df1')
plt.plot(df_2.index, df_2['Unique_idfas_mean'], label='Value from df2')

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Comparison of Two DataFrames')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30, 15))

plt.plot(df_1.index, df_1['unique_ips'], label='Value from df1')
plt.plot(df_2.index, df_2['unique_ips'], label='Value from df2')

plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Comparison of Two DataFrames')
plt.legend()
plt.show()
